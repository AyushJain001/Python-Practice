# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',

'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df_original=df.copy()

# %%
df_original
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df['From_To'].values[0].split('_')
# Out:
# ['LoNDon', 'paris']

# %%
df[['From', 'To']] = df['From_To'].str.split('_', expand=True)
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
df['From']=df['From'].str.capitalize()

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      paris
# 1    Madrid      miLAN
# 2    London  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
df['To']=df['To'].str.capitalize()

# %%
df.drop(['From_To'], axis = 1)
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0       10045.0      [23, 47]               KLM(!)    London      Paris
# 1           NaN            []    <Air France> (12)    Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3           NaN          [13]       12. Air France  Budapest      Paris
# 4       10085.0      [67, 32]          "Swiss Air"  Brussels     London

# %%
df['FlightNumber'].fillna(value=df['FlightNumber'][0]+10, limit=1, inplace=True)
df['FlightNumber'].fillna(value=df['FlightNumber'][2]+10, limit=1, inplace=True)

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
df['FlightNumber'] = df['FlightNumber'].astype(np.int64)

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
delays = pd.DataFrame(df['RecentDelays'].to_list(), columns = ['delay_1', 'delay_2', 'delay_3'])
delays
# Out:
#    delay_1  delay_2  delay_3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN

# %%
df.insert(loc = 3, column='delay_1' , value=delays['delay_1'])
df.insert(loc = 4, column='delay_2' , value=delays['delay_2'])
df.insert(loc = 5, column='delay_3' , value=delays['delay_3'])
df
# Out:
#             From_To  FlightNumber  RecentDelays  delay_1  delay_2  delay_3  \
# 0      LoNDon_paris         10045      [23, 47]     23.0     47.0      NaN
# 1      MAdrid_miLAN         10055            []      NaN      NaN      NaN
# 2  londON_StockhOlm         10065  [24, 43, 87]     24.0     43.0     87.0
# 3    Budapest_PaRis         10075          [13]     13.0      NaN      NaN
# 4   Brussels_londOn         10085      [67, 32]     67.0     32.0      NaN
#
#                Airline      From         To
# 0               KLM(!)    London      Paris
# 1    <Air France> (12)    Madrid      Milan
# 2  (British Airways. )    London  Stockholm
# 3       12. Air France  Budapest      Paris
# 4          "Swiss Air"  Brussels     London

# %%
df.drop(['RecentDelays'],axis=1,inplace=True)

# %%
df.drop(['From_To'],axis=1,inplace=True)

# %%
df
# Out:
#    FlightNumber  delay_1  delay_2  delay_3              Airline      From  \
# 0         10045     23.0     47.0      NaN               KLM(!)    London
# 1         10055      NaN      NaN      NaN    <Air France> (12)    Madrid
# 2         10065     24.0     43.0     87.0  (British Airways. )    London
# 3         10075     13.0      NaN      NaN       12. Air France  Budapest
# 4         10085     67.0     32.0      NaN          "Swiss Air"  Brussels
#
#           To
# 0      Paris
# 1      Milan
# 2  Stockholm
# 3      Paris
# 4     London
